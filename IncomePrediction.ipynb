# %%
import pandas as pd

# %%
df = pd.read_csv('income.csv')

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.education.value_counts()
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %%
df.workclass.value_counts()
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df.occupation.value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df.gender.value_counts()
# Out:
# gender
# Male      32650
# Female    16192
# Name: count, dtype: int64

# %%
if 'occupation' in df.columns:
    df = pd.concat([df.drop('occupation', axis=1), pd.get_dummies(df.occupation).add_prefix('occupation_')], axis=1)

if 'workclass' in df.columns:
    df = pd.concat([df.drop('workclass', axis=1), pd.get_dummies(df.workclass).add_prefix('workclass_')], axis=1)

if 'education' in df.columns:
    df = df.drop('education', axis=1)

if 'marital-status' in df.columns:
    df = pd.concat([df.drop('marital-status', axis=1), pd.get_dummies(df['marital-status']).add_prefix('marital-status_')], axis=1)

if 'relationship' in df.columns:
    df = pd.concat([df.drop('relationship', axis=1), pd.get_dummies(df.relationship).add_prefix('relationship_')], axis=1)

if 'race' in df.columns:
    df = pd.concat([df.drop('race', axis=1), pd.get_dummies(df.race).add_prefix('race_')], axis=1)

if 'native-country' in df.columns:
    df = pd.concat([df.drop('native-country', axis=1), pd.get_dummies(df['native-country']).add_prefix('native-country_')], axis=1)

# %%
df
# Out:
#        age  fnlwgt  educational-num  gender  capital-gain  capital-loss  \
# 0       25  226802                7    Male             0             0
# 1       38   89814                9    Male             0             0
# 2       28  336951               12    Male             0             0
# 3       44  160323               10    Male          7688             0
# 4       18  103497               10  Female             0             0
# ...    ...     ...              ...     ...           ...           ...
# 48837   27  257302               12  Female             0             0
# 48838   40  154374                9    Male             0             0
# 48839   58  151910                9  Female             0             0
# 48840   22  201490                9    Male             0             0
# 48841   52  287927                9  Female         15024             0
#
#        hours-per-week income  occupation_?  occupation_Adm-clerical  ...  \
# ...

# %%
df['gender'] = df['gender'].apply(lambda x: 1 if x == 'Male' else 0)
df['income'] = df['income'].apply(lambda x: 1 if x == '>50K' else 0)  #lambda when used acts as inline function which eliminates the need for creating a separate variable additionally

# %%
df['income']
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 48837    0
# 48838    1
# 48839    0
# 48840    0
# 48841    1
# Name: income, Length: 48842, dtype: int64

# %%
df.columns.values
# Out:
# array(['age', 'fnlwgt', 'educational-num', 'gender', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'income', 'occupation_?',
#        'occupation_Adm-clerical', 'occupation_Armed-Forces',
#        'occupation_Craft-repair', 'occupation_Exec-managerial',
#        'occupation_Farming-fishing', 'occupation_Handlers-cleaners',
#        'occupation_Machine-op-inspct', 'occupation_Other-service',
#        'occupation_Priv-house-serv', 'occupation_Prof-specialty',
#        'occupation_Protective-serv', 'occupation_Sales',
#        'occupation_Tech-support', 'occupation_Transport-moving',
#        'workclass_?', 'workclass_Federal-gov', 'workclass_Local-gov',
#        'workclass_Never-worked', 'workclass_Private',
#        'workclass_Self-emp-inc', 'workclass_Self-emp-not-inc',
#        'workclass_State-gov', 'workclass_Without-pay',
#        'marital-status_Divorced', 'marital-status_Married-AF-spouse',
#        'marital-status_Married-civ-spouse',
# ...

# %%
#dropping the ones that are least imp

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18,12))
sns.heatmap(df.corr(), annot=False, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                                      age    fnlwgt  educational-num    gender  \
# age                             1.000000 -0.076628         0.030940  0.088120
# fnlwgt                         -0.076628  1.000000        -0.038761  0.027739
# educational-num                 0.030940 -0.038761         1.000000  0.009328
# gender                          0.088120  0.027739         0.009328  1.000000
# capital-gain                    0.077229 -0.003706         0.125146  0.047094
# ...                                  ...       ...              ...       ...
# native-country_Thailand        -0.001766 -0.001512         0.007283 -0.007117
# native-country_Trinadad&Tobago  0.001056  0.004153        -0.010201 -0.009342
# native-country_United-States    0.011888 -0.070645         0.104210 -0.011167
# native-country_Vietnam         -0.012337 -0.007479        -0.007544 -0.001545
# native-country_Yugoslavia       0.002905  0.004699        -0.005798  0.005262
#
# ...

# %%
correlations = df.corr()['income'].abs()
sorted_correlations = correlations.sort_values()
num_cols_to_drop = int(0.8* len(df.columns))
cols_to_drop = sorted_correlations.iloc[:num_cols_to_drop].index
df_dropped = df.drop(cols_to_drop, axis=1)

# %%
df_dropped
# Out:
#        age  educational-num  gender  capital-gain  capital-loss  \
# 0       25                7       1             0             0
# 1       38                9       1             0             0
# 2       28               12       1             0             0
# 3       44               10       1          7688             0
# 4       18               10       0             0             0
# ...    ...              ...     ...           ...           ...
# 48837   27               12       0             0             0
# 48838   40                9       1             0             0
# 48839   58                9       0             0             0
# 48840   22                9       1             0             0
# 48841   52                9       0         15024             0
#
#        hours-per-week  income  occupation_Exec-managerial  \
# 0                  40       0                       False
# 1                  50       0                       False
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df_dropped.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
#using random forest since it is decision based at this point

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

df=df.drop('fnlwgt', axis=1)

train_df, test_df = train_test_split(df, test_size=0.2)

# %%
train_df
# Out:
#        age  educational-num  gender  capital-gain  capital-loss  \
# 11602   36                9       1             0             0
# 45792   29               10       1             0             0
# 1256    30               14       1             0             0
# 10601   44               10       1             0             0
# 37786   46               13       1             0             0
# ...    ...              ...     ...           ...           ...
# 41655   29                9       0             0             0
# 23354   56                9       1             0             0
# 45075   21               10       1             0             0
# 45171   30               13       0          3103             0
# 29576   81                2       1             0             0
#
#        hours-per-week  income  occupation_?  occupation_Adm-clerical  \
# 11602              30       0         False                    False
# ...

# %%
test_df
# Out:
#        age  educational-num  gender  capital-gain  capital-loss  \
# 14250   36               11       0             0             0
# 30408   36                9       1             0             0
# 3905    29                9       1             0             0
# 22111   60                9       0             0             0
# 5977    18                9       0             0             0
# ...    ...              ...     ...           ...           ...
# 27877   52               13       1             0             0
# 40127   42                9       0             0             0
# 26145   34               10       1             0             0
# 2695    50               13       0             0             0
# 12590   40               11       1             0             0
#
#        hours-per-week  income  occupation_?  occupation_Adm-clerical  \
# 14250              40       0         False                     True
# ...

# %%
X_train = train_df.drop('income' , axis=1)
y_train = train_df['income']

X_test = test_df.drop('income' , axis=1)
y_test = test_df['income']

# %%
forest = RandomForestClassifier()

forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %% [raw]
# forest.score(X_test,y_test)

# %%
forest.feature_importances_
# Out:
# array([2.30352726e-01, 1.28758789e-01, 1.35087910e-02, 1.10269848e-01,
#        3.77866595e-02, 1.13119480e-01, 1.97154234e-03, 5.04282442e-03,
#        8.99575801e-05, 6.18780236e-03, 1.92319596e-02, 4.57623078e-03,
#        3.51180164e-03, 4.23439381e-03, 7.92769474e-03, 2.53460227e-04,
#        1.55815039e-02, 2.86951157e-03, 6.29944875e-03, 4.33557929e-03,
#        4.22314596e-03, 1.65640604e-03, 4.86740406e-03, 5.37135206e-03,
#        9.42368789e-08, 9.31587604e-03, 5.67596073e-03, 8.19373594e-03,
#        4.07377487e-03, 9.27303782e-05, 6.44979872e-03, 3.68728953e-04,
#        7.66116957e-02, 9.48085348e-04, 2.19023156e-02, 1.76907537e-03,
#        1.88931392e-03, 4.58792322e-02, 8.97868247e-03, 1.89446543e-03,
#        1.18808222e-02, 7.57670948e-03, 1.02902507e-02, 1.45919271e-03,
#        3.02184565e-03, 4.76123383e-03, 9.25406657e-04, 5.96334019e-03,
#        2.82799521e-03, 2.93109796e-04, 1.44646871e-03, 5.40677755e-04,
# ...

# %%
forest.feature_names_in_
# Out:
# array(['age', 'educational-num', 'gender', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'occupation_?', 'occupation_Adm-clerical',
#        'occupation_Armed-Forces', 'occupation_Craft-repair',
#        'occupation_Exec-managerial', 'occupation_Farming-fishing',
#        'occupation_Handlers-cleaners', 'occupation_Machine-op-inspct',
#        'occupation_Other-service', 'occupation_Priv-house-serv',
#        'occupation_Prof-specialty', 'occupation_Protective-serv',
#        'occupation_Sales', 'occupation_Tech-support',
#        'occupation_Transport-moving', 'workclass_?',
#        'workclass_Federal-gov', 'workclass_Local-gov',
#        'workclass_Never-worked', 'workclass_Private',
#        'workclass_Self-emp-inc', 'workclass_Self-emp-not-inc',
#        'workclass_State-gov', 'workclass_Without-pay',
#        'marital-status_Divorced', 'marital-status_Married-AF-spouse',
#        'marital-status_Married-civ-spouse',
#        'marital-status_Married-spouse-absent',
# ...

# %%
dict(zip(forest.feature_names_in_, forest.feature_importances_))
# Out:
# {'age': 0.23035272578897056,
#  'educational-num': 0.12875878930627593,
#  'gender': 0.013508791030398747,
#  'capital-gain': 0.11026984836029896,
#  'capital-loss': 0.037786659457370954,
#  'hours-per-week': 0.1131194802885704,
#  'occupation_?': 0.0019715423435352555,
#  'occupation_Adm-clerical': 0.005042824415435624,
#  'occupation_Armed-Forces': 8.9957580090879e-05,
#  'occupation_Craft-repair': 0.0061878023550875575,
#  'occupation_Exec-managerial': 0.019231959614313832,
#  'occupation_Farming-fishing': 0.004576230781858663,
#  'occupation_Handlers-cleaners': 0.0035118016438938702,
#  'occupation_Machine-op-inspct': 0.004234393806495064,
#  'occupation_Other-service': 0.007927694735151885,
#  'occupation_Priv-house-serv': 0.00025346022694745074,
#  'occupation_Prof-specialty': 0.015581503898322972,
#  'occupation_Protective-serv': 0.0028695115705324775,
#  'occupation_Sales': 0.006299448747163246,
#  'occupation_Tech-support': 0.004335579289885651,
# ...
